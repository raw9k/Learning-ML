# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\rauna\codes\datasets\CreditworthyData.csv")

# %%
df
# Out:
#           Id      city  age sex social_class primary_business  \
# 0          1   Dhanbad   22   F        Mochi        Tailoring
# 1          2  Manjapra   21   F          OBC        Tailoring
# 2          3   Dhanbad   24   M          Nai     Beauty salon
# 3          4       NaN   26   F          OBC        Tailoring
# 4          5   Nuapada   23   F          OBC    General store
# ...      ...       ...  ...  ..          ...              ...
# 39995  39996     Pusad   45   F       Muslim  Buffalo rearing
# 39996  39997     Pusad   35   F           ST        Tailoring
# 39997  39998     Pusad   35   F           Sc     Goat rearing
# 39998  39999     Pusad   28   F           Sc     Goat rearing
# 39999  40000     Pusad   32   F           Sc     Goat rearing
#
#       secondary_business  annual_income  monthly_expenses  old_dependents  \
# 0                 Others        36000.0            5000.0               0
# ...

# %%
df.drop("Id", axis=1, inplace=True)

# %%
df
# Out:
#            city  age sex social_class primary_business secondary_business  \
# 0       Dhanbad   22   F        Mochi        Tailoring             Others
# 1      Manjapra   21   F          OBC        Tailoring               none
# 2       Dhanbad   24   M          Nai     Beauty salon             Others
# 3           NaN   26   F          OBC        Tailoring               none
# 4       Nuapada   23   F          OBC    General store        Agriculture
# ...         ...  ...  ..          ...              ...                ...
# 39995     Pusad   45   F       Muslim  Buffalo rearing               none
# 39996     Pusad   35   F           ST        Tailoring               none
# 39997     Pusad   35   F           Sc     Goat rearing               none
# 39998     Pusad   28   F           Sc     Goat rearing               none
# 39999     Pusad   32   F           Sc     Goat rearing               none
#
#        annual_income  monthly_expenses  old_dependents  young_dependents  \
# ...

# %%
df.shape
# Out:
# (40000, 20)

# %%
df.columns
# Out:
# Index(['city', 'age', 'sex', 'social_class', 'primary_business',
#        'secondary_business', 'annual_income', 'monthly_expenses',
#        'old_dependents', 'young_dependents', 'home_ownership', 'type_of_house',
#        'occupants_count', 'house_area', 'sanitary_availability',
#        'water_availabity', 'loan_purpose', 'loan_tenure', 'loan_installments',
#        'loan_amount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   city                   38136 non-null  object
#  1   age                    40000 non-null  int64
#  2   sex                    40000 non-null  object
#  3   social_class           34745 non-null  object
#  4   primary_business       39974 non-null  object
#  5   secondary_business     34759 non-null  object
#  6   annual_income          40000 non-null  float64
#  7   monthly_expenses       39880 non-null  float64
#  8   old_dependents         40000 non-null  int64
#  9   young_dependents       40000 non-null  int64
#  10  home_ownership         39621 non-null  float64
#  11  type_of_house          39306 non-null  object
#  12  occupants_count        40000 non-null  int64
#  13  house_area             40000 non-null  float64
# ...

# %%
df.isna().sum()
# Out:
# city                     1864
# age                         0
# sex                         0
# social_class             5255
# primary_business           26
# secondary_business       5241
# annual_income               0
# monthly_expenses          120
# old_dependents              0
# young_dependents            0
# home_ownership            379
# type_of_house             694
# occupants_count             0
# house_area                  0
# sanitary_availability     208
# water_availabity         5253
# loan_purpose               26
# loan_tenure                 0
# loan_installments           0
# loan_amount                 0
# dtype: int64

# %%
df
# Out:
#            city  age sex social_class primary_business secondary_business  \
# 0       Dhanbad   22   F        Mochi        Tailoring             Others
# 1      Manjapra   21   F          OBC        Tailoring               none
# 2       Dhanbad   24   M          Nai     Beauty salon             Others
# 3           NaN   26   F          OBC        Tailoring               none
# 4       Nuapada   23   F          OBC    General store        Agriculture
# ...         ...  ...  ..          ...              ...                ...
# 39995     Pusad   45   F       Muslim  Buffalo rearing               none
# 39996     Pusad   35   F           ST        Tailoring               none
# 39997     Pusad   35   F           Sc     Goat rearing               none
# 39998     Pusad   28   F           Sc     Goat rearing               none
# 39999     Pusad   32   F           Sc     Goat rearing               none
#
#        annual_income  monthly_expenses  old_dependents  young_dependents  \
# ...

# %%
df.describe()
# Out:
#                 age  annual_income  monthly_expenses  old_dependents  \
# count   40000.00000   4.000000e+04      39880.000000    40000.000000
# mean       55.15990   3.764021e+04       3810.875401        0.044900
# std      3830.35566   2.873912e+04       4592.958009        0.222003
# min         2.00000   0.000000e+00          2.000000        0.000000
# 25%        29.00000   1.440000e+04       2500.000000        0.000000
# 50%        35.00000   3.600000e+04       3500.000000        0.000000
# 75%        42.00000   5.600000e+04       4000.000000        0.000000
# max    766105.00000   1.200000e+06     240000.000000        3.000000
#
#        young_dependents  home_ownership  occupants_count     house_area  \
# count       40000.00000    39621.000000     40000.000000   40000.000000
# mean            1.13710        0.972489        26.641000     552.804750
# std             1.07384        0.163568      4749.995485    4596.921905
# ...

# %%
num_col = df.select_dtypes(exclude="object")
cat_col = df.select_dtypes(include="object")

# %%
num_col
# Out:
#        age  annual_income  monthly_expenses  old_dependents  young_dependents  \
# 0       22        36000.0            5000.0               0                 2
# 1       21        94000.0            3600.0               1                 1
# 2       24        48000.0            4000.0               0                 2
# 3       26         7000.0            5000.0               0                 2
# 4       23        36000.0            3500.0               0                 0
# ...    ...            ...               ...             ...               ...
# 39995   45        78000.0            4000.0               0                 0
# 39996   35        48000.0            4000.0               0                 3
# 39997   35        48000.0            3500.0               0                 2
# 39998   28        48000.0            4000.0               0                 3
# 39999   32        72000.0            4500.0               0                 2
#
# ...

# %%
cat_col
# Out:
#            city sex social_class primary_business secondary_business  \
# 0       Dhanbad   F        Mochi        Tailoring             Others
# 1      Manjapra   F          OBC        Tailoring               none
# 2       Dhanbad   M          Nai     Beauty salon             Others
# 3           NaN   F          OBC        Tailoring               none
# 4       Nuapada   F          OBC    General store        Agriculture
# ...         ...  ..          ...              ...                ...
# 39995     Pusad   F       Muslim  Buffalo rearing               none
# 39996     Pusad   F           ST        Tailoring               none
# 39997     Pusad   F           Sc     Goat rearing               none
# 39998     Pusad   F           Sc     Goat rearing               none
# 39999     Pusad   F           Sc     Goat rearing               none
#
#       type_of_house      loan_purpose
# 0                 R          Apparels
# 1                T1          Apparels
# ...

# %%
corr_df = num_col.corr()

# %%
corr_df
# Out:
#                             age  annual_income  monthly_expenses  \
# age                    1.000000      -0.006414         -0.003101
# annual_income         -0.006414       1.000000          0.112499
# monthly_expenses      -0.003101       0.112499          1.000000
# old_dependents        -0.000691       0.062216         -0.003522
# young_dependents      -0.005837       0.239864          0.028754
# home_ownership         0.000937       0.011885         -0.047173
# occupants_count       -0.000031       0.003999          0.001320
# house_area            -0.000586       0.033902         -0.008270
# sanitary_availability -0.007487       0.241509          0.059819
# water_availabity      -0.001627       0.280939          0.078061
# loan_tenure           -0.000233      -0.027618         -0.013020
# loan_installments     -0.003040      -0.119936          0.113914
# loan_amount           -0.001969       0.085632          0.019569
#
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data = corr_df, annot=True ,cmap="magma")
# Out:
# <Axes: >

# %%
df["city"].value_counts()
# Out:
# city
# Pusad               3154
# Bahoriband          1979
# PUSAD               1776
# Shantipur           1727
# Imphal              1699
#                     ...
# Soro                   1
# Kendreapara            1
# Birabalbhadrapur       1
# Navin Pusad            1
# KODANGAL               1
# Name: count, Length: 856, dtype: int64

# %%
df["type_of_house"].value_counts()
# Out:
# type_of_house
# T2    17715
# T1    15092
# R      6499
# Name: count, dtype: int64

# %%
df["sex"].value_counts()
# Out:
# sex
# F     37622
# M      2371
# TG        7
# Name: count, dtype: int64

# %%
df["social_class"].value_counts()
# Out:
# social_class
# OBC        10683
# SC          3136
# ST          2616
# General     2299
# Muslim      1743
#            ...
# Broman         1
# ABC            1
# oc             1
# Gorai          1
# GEN.           1
# Name: count, Length: 519, dtype: int64

# %%
#city	sex	social_class	primary_business	secondary_business	type_of_house	loan_purpose

# %%
df["primary_business"].unique()
# Out:
# array(['Tailoring', 'Beauty salon', 'General store',
#        'Puffed rice business', 'Poultry farm', 'Tea stall', 'Cow Rearing',
#        'Vegetable vendor', 'Banana Cultivation', 'Utensils selling',
#        'Readymade Garments', 'Medical shop', 'Electronic goods shop',
#        'Milk business', 'Grocery store', 'Carpenter/Wood business',
#        'Goat rearing', 'Vegetable cultivation', 'Cattle rearing',
#        'Brick manufacturing unit', 'Buffalo rearing', 'Wet grinding',
#        'Petty shop', 'Rice business', 'Tiffin center', 'Betel shop',
#        'Cycle repair shop', 'Bakery', 'Gram cultivation', 'Sweets shop',
#        'Fancy Store', 'Laundry', 'Provision store', 'Snacks business',
#        'Beauty parlour', 'Beedi rolling business', 'Eggs selling',
#        'Embroidery work', 'Helmets selling', 'Auto Rickshaw',
#        'Fish vendor', 'Artificial Flower Making', 'Paddy cultivation',
#        'Leaf plate making', 'Stationery Shop', 'Paddy processing',
# ...

# %%
df["secondary_business"].value_counts()
# Out:
# secondary_business
# none                   27366
# Others                  2564
# Daily wage labourer     2545
# Agriculture             2105
# Livestock rearing        179
# Name: count, dtype: int64

# %%
df["loan_purpose"].value_counts()
# Out:
# loan_purpose
# Apparels                           7064
# Agro Based Businesses              4729
# Animal husbandry                   4421
# Meat Businesses                    4302
# Handicrafts                        4230
# Farming/ Agriculture               3284
# Education Loan                     2100
# Retail Store                       1963
# Eateries                           1831
# Business Services - II              854
# Tobacco Related Activities          853
# Construction Related Activities     661
# Retail Sale                         614
# Artifical Jewellry Selling          556
# Carpentery work                     299
# Food Items                          285
# Business Services - I               276
# Transportation Services             245
# Flower Business                     238
# Beauty Salon                        204
# Repair Services                     192
# Laundry Services                    162
# Agarbatti Business                  107
# ...
