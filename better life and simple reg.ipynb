# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn

# %%
oecddf = pd.read_csv(r"C:\Users\rauna\codes\datasets\BetterLifeIndex2015.csv", thousands=',')

# %%
oecddf.head()
# Out:
#      Country    Dwellings without basic facilities    Housing expenditure  \
# 0  Australia                                   1.1                     20
# 1    Austria                                   1.0                     21
# 2    Belgium                                   2.0                     21
# 3     Canada                                   0.2                     21
# 4      Chile                                   9.4                     18
#
#      Rooms per person    Household net adjusted disposable income  \
# 0                 2.3                                       31588
# 1                 1.6                                       31173
# 2                 2.2                                       28307
# 3                 2.5                                       29365
# 4                 1.2                                       14533
#
#      Household net financial wealth    Employment rate    Job security  \
# ...

# %%
oecddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 25 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Country                                      36 non-null     object
#  1     Dwellings without basic facilities         36 non-null     float64
#  2     Housing expenditure                        36 non-null     int64
#  3     Rooms per person                           36 non-null     float64
#  4     Household net adjusted disposable income   36 non-null     int64
#  5     Household net financial wealth             36 non-null     int64
#  6     Employment rate                            36 non-null     int64
#  7     Job security                               36 non-null     float64
#  8     Long-term unemployment rate                36 non-null     float64
# ...

# %%
gdpdf = pd.read_csv(r"C:\Users\rauna\codes\datasets\gdp_per_capita.csv",  thousands=',', delimiter="\t", encoding="latin1",na_values="n/a")

# %%
gdpdf
# Out:
#                                                Country  \
# 0                                          Afghanistan
# 1                                              Albania
# 2                                              Algeria
# 3                                               Angola
# 4                                  Antigua and Barbuda
# ..                                                 ...
# 185                                            Vietnam
# 186                                              Yemen
# 187                                             Zambia
# 188                                           Zimbabwe
# 189  International Monetary Fund, World Economic Ou...
#
#                                     Subject Descriptor         Units  Scale  \
# 0    Gross domestic product per capita, current prices  U.S. dollars  Units
# 1    Gross domestic product per capita, current prices  U.S. dollars  Units
# ...

# %%
gdpdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        190 non-null    object
#  1   Subject Descriptor             189 non-null    object
#  2   Units                          189 non-null    object
#  3   Scale                          189 non-null    object
#  4   Country/Series-specific Notes  188 non-null    object
#  5   2015                           187 non-null    float64
#  6   Estimates Start After          188 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 10.5+ KB

# %%
merged_df = pd.merge(oecddf, gdpdf, on="Country", how="inner")

# %%
merged_df.head()
# Out:
#      Country    Dwellings without basic facilities    Housing expenditure  \
# 0  Australia                                   1.1                     20
# 1    Austria                                   1.0                     21
# 2    Belgium                                   2.0                     21
# 3     Canada                                   0.2                     21
# 4      Chile                                   9.4                     18
#
#      Rooms per person    Household net adjusted disposable income  \
# 0                 2.3                                       31588
# 1                 1.6                                       31173
# 2                 2.2                                       28307
# 3                 2.5                                       29365
# 4                 1.2                                       14533
#
#      Household net financial wealth    Employment rate    Job security  \
# ...

# %%
sorted_df = merged_df.sort_values(by="2015", ascending=False)

# %%
print(sorted_df.head)
# Out:
# <bound method NDFrame.head of             Country    Dwellings without basic facilities  \
# 19       Luxembourg                                   0.1
# 30      Switzerland                                   0.0
# 23           Norway                                   0.3
# 33    United States                                   0.1
# 6           Denmark                                   0.9
# 14          Ireland                                   0.2
# 0         Australia                                   1.1
# 13          Iceland                                   0.4
# 29           Sweden                                   0.0
# 32   United Kingdom                                   0.2
# 1           Austria                                   1.0
# 21      Netherlands                                   0.0
# 3            Canada                                   0.2
# 8           Finland                                   0.6
# 10          Germany                                   0.1
# ...

# %% [markdown]
# # Simple linear Reg

# %%
x = 2* np.random.rand(100,1)
y = 4 + 3*x + np.random.randn(100,1)

# %%
plt.plot(x,y, ".")

# %%
xb = np.c_[np.ones((100,1)), x]

# %%
xb
# Out:
# array([[1.        , 1.81204332],
#        [1.        , 0.32189338],
#        [1.        , 0.58820049],
#        [1.        , 1.93520227],
#        [1.        , 0.97331114],
#        [1.        , 0.91879282],
#        [1.        , 0.62580834],
#        [1.        , 0.01379538],
#        [1.        , 0.9914607 ],
#        [1.        , 0.97614718],
#        [1.        , 1.46742831],
#        [1.        , 0.74687827],
#        [1.        , 0.33265512],
#        [1.        , 1.00189348],
#        [1.        , 1.26424976],
#        [1.        , 1.17228034],
#        [1.        , 1.93458545],
#        [1.        , 0.55341464],
#        [1.        , 0.30239749],
#        [1.        , 1.14355502],
#        [1.        , 0.70850267],
#        [1.        , 0.45706186],
#        [1.        , 1.26162159],
#        [1.        , 0.32436664],
#        [1.        , 0.38680049],
#        [1.        , 0.93505524],
#        [1.        , 0.23561212],
#        [1.        , 1.75348075],
# ...

# %%
thetha_best = np.linalg.inv(xb.T.dot(xb)).dot(xb.T).dot(y)

# %%
thetha_best
# Out:
# array([[4.00420796],
#        [3.14859522]])

# %%
x_new = np.array([[0],[2]])

# %%
x_new
# Out:
# array([[0],
#        [2]])

# %%
x_new_b = np.c_[np.ones((2,1)), x_new]
y_pred = x_new_b.dot(thetha_best)

# %%
y_pred
# Out:
# array([[ 4.00420796],
#        [10.30139841]])

# %%
plt.plot(x_new, y_pred,"r-")
plt.plot(x,y,"b.")
plt.axis([0,2,0,15])
plt.show()

# %%
plt.plot(x_new, y_pred,"r-")
plt.axis([0,2,0,15])
# Out:
# (np.float64(0.0), np.float64(2.0), np.float64(0.0), np.float64(15.0))

# %%
plt.plot(x,y,"b.")

# %%
plt.axis([0,2,0,15])
# Out:
# (np.float64(0.0), np.float64(2.0), np.float64(0.0), np.float64(15.0))
