# %% [markdown]
# # Boosting algorithm for Classification

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
travel = pd.read_csv(r"C:\Users\rauna\codes\datasets\Travel.csv")

# %%
travel.head()
# Out:
#    CustomerID  ProdTaken  ...  Designation MonthlyIncome
# 0      200000          1  ...      Manager       20993.0
# 1      200001          0  ...      Manager       20130.0
# 2      200002          1  ...    Executive       17090.0
# 3      200003          0  ...    Executive       17909.0
# 4      200004          0  ...    Executive       18468.0
#
# [5 rows x 20 columns]

# %%
travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
travel.describe()
# Out:
#           CustomerID    ProdTaken  ...  NumberOfChildrenVisiting  MonthlyIncome
# count    4888.000000  4888.000000  ...               4822.000000    4655.000000
# mean   202443.500000     0.188216  ...                  1.187267   23619.853491
# std      1411.188388     0.390925  ...                  0.857861    5380.698361
# min    200000.000000     0.000000  ...                  0.000000    1000.000000
# 25%    201221.750000     0.000000  ...                  1.000000   20346.000000
# 50%    202443.500000     0.000000  ...                  1.000000   22347.000000
# 75%    203665.250000     0.000000  ...                  2.000000   25571.000000
# max    204887.000000     1.000000  ...                  3.000000   98678.000000
#
# [8 rows x 14 columns]

# %%
travel.isna().sum()
# Out:
# CustomerID                    0
# ProdTaken                     0
# Age                         226
# TypeofContact                25
# CityTier                      0
# DurationOfPitch             251
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            45
# ProductPitched                0
# PreferredPropertyStar        26
# MaritalStatus                 0
# NumberOfTrips               140
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     66
# Designation                   0
# MonthlyIncome               233
# dtype: int64

# %%
travel.shape
# Out:
# (4888, 20)

# %% [markdown]
# we need to check that data has correct spelling or not

# %%
travel['Gender'].value_counts()
# Out:
# Gender
# Male       2916
# Female     1817
# Fe Male     155
# Name: count, dtype: int64

# %%
travel['Gender'] = travel['Gender'].replace("Fe Male","Female")

# %%
travel['Gender'].value_counts()
# Out:
# Gender
# Male      2916
# Female    1972
# Name: count, dtype: int64

# %%
travel['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married      2340
# Divorced      950
# Single        916
# Unmarried     682
# Name: count, dtype: int64

# %%
travel['MaritalStatus'] = travel['MaritalStatus'].replace("Unmarried","Single")

# %%
travel['MaritalStatus'].value_counts()
# Out:
# MaritalStatus
# Married     2340
# Single      1598
# Divorced     950
# Name: count, dtype: int64

# %%
travel['TypeofContact'].value_counts()
# Out:
# TypeofContact
# Self Enquiry       3444
# Company Invited    1419
# Name: count, dtype: int64

# %%
travel['Occupation'].value_counts()
# Out:
# Occupation
# Salaried          2368
# Small Business    2084
# Large Business     434
# Free Lancer          2
# Name: count, dtype: int64

# %%
travel['ProductPitched'].value_counts()
# Out:
# ProductPitched
# Basic           1842
# Deluxe          1732
# Standard         742
# Super Deluxe     342
# King             230
# Name: count, dtype: int64

# %%
travel['Designation'].value_counts()
# Out:
# Designation
# Executive         1842
# Manager           1732
# Senior Manager     742
# AVP                342
# VP                 230
# Name: count, dtype: int64

# %%
features_with_na = [i for i in travel.columns if travel[i].isnull().sum()>=1]

for i in features_with_na:
    print(i, travel[i].isnull().mean()*100, "% missing value")
# Out:
# Age 4.623567921440261 % missing value
# TypeofContact 0.5114566284779051 % missing value
# DurationOfPitch 5.1350245499181675 % missing value
# NumberOfFollowups 0.9206219312602291 % missing value
# PreferredPropertyStar 0.5319148936170213 % missing value
# NumberOfTrips 2.8641571194762685 % missing value
# NumberOfChildrenVisiting 1.3502454991816693 % missing value
# MonthlyIncome 4.766775777414075 % missing value

# %%
features_with_na
# Out:
# ['Age',
#  'TypeofContact',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %%
travel.describe(exclude="object")
# Out:
#           CustomerID    ProdTaken  ...  NumberOfChildrenVisiting  MonthlyIncome
# count    4888.000000  4888.000000  ...               4822.000000    4655.000000
# mean   202443.500000     0.188216  ...                  1.187267   23619.853491
# std      1411.188388     0.390925  ...                  0.857861    5380.698361
# min    200000.000000     0.000000  ...                  0.000000    1000.000000
# 25%    201221.750000     0.000000  ...                  1.000000   20346.000000
# 50%    202443.500000     0.000000  ...                  1.000000   22347.000000
# 75%    203665.250000     0.000000  ...                  2.000000   25571.000000
# max    204887.000000     1.000000  ...                  3.000000   98678.000000
#
# [8 rows x 14 columns]

# %%
travel[features_with_na].describe(exclude="object")
# Out:
#                Age  DurationOfPitch  ...  NumberOfChildrenVisiting  MonthlyIncome
# count  4662.000000      4637.000000  ...               4822.000000    4655.000000
# mean     37.622265        15.490835  ...                  1.187267   23619.853491
# std       9.316387         8.519643  ...                  0.857861    5380.698361
# min      18.000000         5.000000  ...                  0.000000    1000.000000
# 25%      31.000000         9.000000  ...                  1.000000   20346.000000
# 50%      36.000000        13.000000  ...                  1.000000   22347.000000
# 75%      44.000000        20.000000  ...                  2.000000   25571.000000
# max      61.000000       127.000000  ...                  3.000000   98678.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# Note: If mean and 50% values are close that mean we dont have outliers

# %%
sns.boxplot(x = travel["DurationOfPitch"], data= travel)
plt.show()

# %%
for i in travel:
    plt.figure(figsize=(8,4))
    plot = sns.boxplot(x = travel[i],legend="auto")
    print(plot)
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)
# Axes(0.125,0.11;0.775x0.77)

# %%
sns.pairplot(travel)

# %%
sns.countplot(x="Age", data=travel, palette="ch:.25",)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(8,4))
sns.countplot(x = travel.DurationOfPitch, palette="ch:.25")
# Out:
# <Axes: xlabel='DurationOfPitch', ylabel='count'>

# %%
travel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4888 entries, 0 to 4887
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CustomerID                4888 non-null   int64
#  1   ProdTaken                 4888 non-null   int64
#  2   Age                       4662 non-null   float64
#  3   TypeofContact             4863 non-null   object
#  4   CityTier                  4888 non-null   int64
#  5   DurationOfPitch           4637 non-null   float64
#  6   Occupation                4888 non-null   object
#  7   Gender                    4888 non-null   object
#  8   NumberOfPersonVisiting    4888 non-null   int64
#  9   NumberOfFollowups         4843 non-null   float64
#  10  ProductPitched            4888 non-null   object
#  11  PreferredPropertyStar     4862 non-null   float64
#  12  MaritalStatus             4888 non-null   object
# ...

# %%
features_with_na
# Out:
# ['Age',
#  'TypeofContact',
#  'DurationOfPitch',
#  'NumberOfFollowups',
#  'PreferredPropertyStar',
#  'NumberOfTrips',
#  'NumberOfChildrenVisiting',
#  'MonthlyIncome']

# %% [markdown]
# Imputation for Features with NaN
# 1) For int values, we will use meadian
# 2) For categorical values we will use mode

# %%
travel["Age"].fillna(travel["Age"].median(), inplace= True)
travel["DurationOfPitch"].fillna(travel["DurationOfPitch"].median(), inplace= True)
travel["NumberOfTrips"].fillna(travel["NumberOfTrips"].median(), inplace= True)
travel["MonthlyIncome"].fillna(travel["MonthlyIncome"].median(), inplace= True)
travel["PreferredPropertyStar"].fillna(travel["PreferredPropertyStar"].mode()[0], inplace= True)
travel["TypeofContact"].fillna(travel["TypeofContact"].mode()[0], inplace= True)
travel["NumberOfFollowups"].fillna(travel["NumberOfFollowups"].mode()[0], inplace= True)
travel["NumberOfChildrenVisiting"].fillna(travel["NumberOfChildrenVisiting"].mode()[0], inplace= True)

# %%
travel.isnull().sum()
# Out:
# CustomerID                  0
# ProdTaken                   0
# Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# dtype: int64

# %%
travel.head()
# Out:
#    CustomerID  ProdTaken  ...  Designation MonthlyIncome
# 0      200000          1  ...      Manager       20993.0
# 1      200001          0  ...      Manager       20130.0
# 2      200002          1  ...    Executive       17090.0
# 3      200003          0  ...    Executive       17909.0
# 4      200004          0  ...    Executive       18468.0
#
# [5 rows x 20 columns]

# %%
travel.drop("CustomerID", inplace= True, axis=1)

# %%
travel.head()
# Out:
#    ProdTaken   Age  ... Designation  MonthlyIncome
# 0          1  41.0  ...     Manager        20993.0
# 1          0  49.0  ...     Manager        20130.0
# 2          1  37.0  ...   Executive        17090.0
# 3          0  33.0  ...   Executive        17909.0
# 4          0  36.0  ...   Executive        18468.0
#
# [5 rows x 19 columns]

# %%
travel["TotalVisiting"] = travel["NumberOfPersonVisiting"] + travel["NumberOfChildrenVisiting"]
travel.drop(columns=["NumberOfPersonVisiting", "NumberOfChildrenVisiting"], inplace = True, axis=1)

# %%
travel.head()
# Out:
#    ProdTaken   Age    TypeofContact  ...  Designation  MonthlyIncome TotalVisiting
# 0          1  41.0     Self Enquiry  ...      Manager        20993.0           3.0
# 1          0  49.0  Company Invited  ...      Manager        20130.0           5.0
# 2          1  37.0     Self Enquiry  ...    Executive        17090.0           3.0
# 3          0  33.0  Company Invited  ...    Executive        17909.0           3.0
# 4          0  36.0     Self Enquiry  ...    Executive        18468.0           2.0
#
# [5 rows x 18 columns]

# %%
num_features = [features for features in travel.columns if travel[features].dtype != "O" ]
print(num_features)
print("Number of Numerical features:",len(num_features))
# Out:
# ['ProdTaken', 'Age', 'CityTier', 'DurationOfPitch', 'NumberOfFollowups', 'PreferredPropertyStar', 'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar', 'MonthlyIncome', 'TotalVisiting']
# Number of Numerical features: 12

# %%
cat_features = [features for features in travel.columns if travel[features].dtype == "O" ]
print(cat_features)
print("Number of Categorical features:",len(cat_features))
# Out:
# ['TypeofContact', 'Occupation', 'Gender', 'ProductPitched', 'MaritalStatus', 'Designation']
# Number of Categorical features: 6

# %%
num_features =[]
cat_features =[]
dis_features =[]
con_features =[]
for i in travel.columns:
    features = travel[i].dtype
    if features != "O":
        num_features.append(travel[i])
    elif features == "O":
        cat_features.append(travel[i])

print("Number of Numerical features:",len(num_features))
print("Number of Categorical features:",len(cat_features))
# Out:
# Number of Numerical features: 12
# Number of Categorical features: 6

# %%
from sklearn.model_selection import train_test_split

# %%
x = travel.drop(["ProdTaken"], axis=1)
y = travel["ProdTaken"]

# %%
y.value_counts()
# Out:
# ProdTaken
# 0    3968
# 1     920
# Name: count, dtype: int64

# %%
x.head()
# Out:
#     Age    TypeofContact  CityTier  ...  Designation MonthlyIncome TotalVisiting
# 0  41.0     Self Enquiry         3  ...      Manager       20993.0           3.0
# 1  49.0  Company Invited         1  ...      Manager       20130.0           5.0
# 2  37.0     Self Enquiry         1  ...    Executive       17090.0           3.0
# 3  33.0  Company Invited         1  ...    Executive       17909.0           3.0
# 4  36.0     Self Enquiry         1  ...    Executive       18468.0           2.0
#
# [5 rows x 17 columns]

# %%
travel["TypeofContact"].unique()
# Out:
# array(['Self Enquiry', 'Company Invited'], dtype=object)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train.shape, x_test.shape
# Out:
# ((3910, 17), (978, 17))

# %%
cat_features = x.select_dtypes(include="object").columns
num_features = x.select_dtypes(exclude="object").columns

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
from sklearn.compose import ColumnTransformer

# %%
scalar = StandardScaler()
encoder = OneHotEncoder(drop="first")

# %%
preprocessor = ColumnTransformer(
    [
        ("OneHotEncoder", encoder, cat_features),
        ("StandardScaler", scalar, num_features)
    ]
)

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('OneHotEncoder', OneHotEncoder(drop='first'),
#                                  Index(['TypeofContact', 'Occupation', 'Gender', 'ProductPitched',
#        'MaritalStatus', 'Designation'],
#       dtype='object')),
#                                 ('StandardScaler', StandardScaler(),
#                                  Index(['Age', 'CityTier', 'DurationOfPitch', 'NumberOfFollowups',
#        'PreferredPropertyStar', 'NumberOfTrips', 'Passport',
#        'PitchSatisfactionScore', 'OwnCar', 'MonthlyIncome', 'TotalVisiting'],
#       dtype='object'))])

# %%
x_train = preprocessor.fit_transform(x_train)

# %%
x_test = preprocessor.transform(x_test)

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
models = {
    "DecisionTreeClassifier": DecisionTreeClassifier(),
    "Random Forest" : RandomForestClassifier(),
    "Gradient Boost" : GradientBoostingClassifier(),
    "Adaboost" : AdaBoostClassifier()
}

for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train)
    
    # Make Prediction
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred)
    model_train_f1 = f1_score(y_train, y_train_pred, average="weighted")
    model_train_recall = recall_score(y_train, y_train_pred)
    model_train_roc = roc_auc_score(y_train, y_train_pred)
    model_train_precision = precision_score(y_train, y_train_pred)
    
    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred)
    model_test_f1 = f1_score(y_test, y_test_pred, average="weighted")
    model_test_recall = recall_score(y_test, y_test_pred)
    model_test_roc = roc_auc_score(y_test, y_test_pred)
    model_test_precision = precision_score(y_test, y_test_pred)

    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_roc))
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_roc))

    print('----------------------------------')

    print("classification_report for Test Dataset")
    print(classification_report(y_test,y_test_pred))

    print('----------------------------------')

    print("confusion_matrix for Test Dataset")
    print(confusion_matrix(y_test,y_test_pred))

    print('='*35)
    print('\n')
# Out:
# DecisionTreeClassifier
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9274
# - F1 score: 0.9264
# - Precision: 0.8371
# - Recall: 0.7801
# - Roc Auc Score: 0.8716
# ----------------------------------
# classification_report for Test Dataset
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       787
#            1       0.84      0.78      0.81       191
#
#     accuracy                           0.93       978
#    macro avg       0.89      0.87      0.88       978
# weighted avg       0.93      0.93      0.93       978
#
# ----------------------------------
# confusion_matrix for Test Dataset
# [[758  29]
#  [ 42 149]]
# ...
#
#
# Random Forest
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# ...

# %% [markdown]
# ### Hyperparameter Training for Adaboost

# %%
adaboost_param = {
    "n_estimators": [50,60,70,80,90,100,120],
    "learning_rate":[0.3,0.5,0.7,1],
    "algorithm":['SAMME', 'SAMME.R'],
}

# %%
adaboost_param
# Out:
# {'n_estimators': [50, 60, 70, 80, 90, 100, 120],
#  'learning_rate': [0.3, 0.5, 0.7, 1],
#  'algorithm': ['SAMME', 'SAMME.R']}

# %%
randomcv_models = [
    ("adaboost", AdaBoostClassifier(), adaboost_param)
]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=3,
                                   n_jobs=-1)
    random.fit(x_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 56 candidates, totalling 168 fits
# ---------------- Best Params for adaboost -------------------
# {'n_estimators': 80, 'learning_rate': 1, 'algorithm': 'SAMME'}

# %%
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
models={
    "Adaboost": AdaBoostClassifier(n_estimators=80, learning_rate=1, algorithm='SAMME')
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted') # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

    
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))

    print('----------------------------------')
    print("classification_report for Test Dataset")
    print(classification_report(y_test,y_test_pred))
    
    print('----------------------------------')
    
    print("confusion_matrix for Test Dataset")
    print(confusion_matrix(y_test,y_test_pred))


    print('-'*35)
    print('\n')
# Out:
# Adaboost
# Model performance for Training set
# - Accuracy: 0.8465
# - F1 score: 0.8132
# - Precision: 0.7699
# - Recall: 0.2524
# - Roc Auc Score: 0.6176
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.8364
# - F1 score: 0.7977
# - Precision: 0.7818
# - Recall: 0.2251
# - Roc Auc Score: 0.6049
# ----------------------------------
# classification_report for Test Dataset
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.91       787
#            1       0.78      0.23      0.35       191
#
#     accuracy                           0.84       978
#    macro avg       0.81      0.60      0.63       978
# weighted avg       0.83      0.84      0.80       978
#
# ----------------------------------
# confusion_matrix for Test Dataset
# [[775  12]
#  [148  43]]
# -----------------------------------

# %%
## Plot ROC AUC Curve
from sklearn.metrics import roc_auc_score,roc_curve
plt.figure()

# Add the models to the list that you want to view on the ROC plot
auc_models = [
{
    'label': 'Adaboost Classifier',
    'model': AdaBoostClassifier(n_estimators = 60, learning_rate = 0.5, algorithm = 'SAMME.R'),
    'auc':  0.6049
},
    
]
# create loop through all model
for algo in auc_models:
    model = algo['model'] # select the model
    model.fit(x_train, y_train) # train the model
# Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:,1])
# Calculate Area under the curve to display on the plot
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (algo['label'], algo['auc']))
# Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### Hyperparameter Training for Gradientboost

# %%
gradient_params={
    "loss": ['log_loss', 'deviance', 'exponential'],
    "criterion": ['friedman_mse', 'squared_error', 'mse'],
    "min_samples_split": [2, 8, 15, 20],
    "n_estimators": [100, 200, 500, 1000],
    "max_depth": [5, 8, 15, None, 10]
}

# %%
randomcv_models = [
    ("Gradient boost", GradientBoostingClassifier(), gradient_params)
]

# %%
from sklearn.model_selection import RandomizedSearchCV

model_param = {}
for name, model, params in randomcv_models:
    random = RandomizedSearchCV(estimator=model,
                                   param_distributions=params,
                                   n_iter=100,
                                   cv=3,
                                   verbose=3,
                                   n_jobs=-1)
    random.fit(x_train, y_train)
    model_param[name] = random.best_params_

for model_name in model_param:
    print(f"---------------- Best Params for {model_name} -------------------")
    print(model_param[model_name])
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# ---------------- Best Params for Gradient boost -------------------
# {'n_estimators': 1000, 'min_samples_split': 15, 'max_depth': 15, 'loss': 'exponential', 'criterion': 'squared_error'}

# %%
from sklearn.metrics import accuracy_score, classification_report, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, roc_auc_score, roc_curve
models={
    "Gradient Boost": GradientBoostingClassifier(n_estimators=1000, min_samples_split=15,max_depth=15,loss="exponential",criterion="squared_error")
}
for i in range(len(list(models))):
    model = list(models.values())[i]
    model.fit(x_train, y_train) # Train model

    # Make predictions
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    # Training set performance
    model_train_accuracy = accuracy_score(y_train, y_train_pred) # Calculate Accuracy
    model_train_f1 = f1_score(y_train, y_train_pred, average='weighted') # Calculate F1-score
    model_train_precision = precision_score(y_train, y_train_pred) # Calculate Precision
    model_train_recall = recall_score(y_train, y_train_pred) # Calculate Recall
    model_train_rocauc_score = roc_auc_score(y_train, y_train_pred)


    # Test set performance
    model_test_accuracy = accuracy_score(y_test, y_test_pred) # Calculate Accuracy
    model_test_f1 = f1_score(y_test, y_test_pred, average='weighted') # Calculate F1-score
    model_test_precision = precision_score(y_test, y_test_pred) # Calculate Precision
    model_test_recall = recall_score(y_test, y_test_pred) # Calculate Recall
    model_test_rocauc_score = roc_auc_score(y_test, y_test_pred) #Calculate Roc


    print(list(models.keys())[i])
    
    print('Model performance for Training set')
    print("- Accuracy: {:.4f}".format(model_train_accuracy))
    print('- F1 score: {:.4f}'.format(model_train_f1))
    
    print('- Precision: {:.4f}'.format(model_train_precision))
    print('- Recall: {:.4f}'.format(model_train_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_train_rocauc_score))

    
    
    print('----------------------------------')
    
    print('Model performance for Test set')
    print('- Accuracy: {:.4f}'.format(model_test_accuracy))
    print('- F1 score: {:.4f}'.format(model_test_f1))
    print('- Precision: {:.4f}'.format(model_test_precision))
    print('- Recall: {:.4f}'.format(model_test_recall))
    print('- Roc Auc Score: {:.4f}'.format(model_test_rocauc_score))

    print('----------------------------------')
    print("classification_report for Test Dataset")
    print(classification_report(y_test,y_test_pred))
    
    print('----------------------------------')
    
    print("confusion_matrix for Test Dataset")
    print(confusion_matrix(y_test,y_test_pred))


    print('-'*35)
    print('\n')
# Out:
# Gradient Boost
# Model performance for Training set
# - Accuracy: 1.0000
# - F1 score: 1.0000
# - Precision: 1.0000
# - Recall: 1.0000
# - Roc Auc Score: 1.0000
# ----------------------------------
# Model performance for Test set
# - Accuracy: 0.9591
# - F1 score: 0.9577
# - Precision: 0.9689
# - Recall: 0.8168
# - Roc Auc Score: 0.9052
# ----------------------------------
# classification_report for Test Dataset
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       787
#            1       0.97      0.82      0.89       191
#
#     accuracy                           0.96       978
#    macro avg       0.96      0.91      0.93       978
# weighted avg       0.96      0.96      0.96       978
#
# ----------------------------------
# confusion_matrix for Test Dataset
# [[782   5]
#  [ 35 156]]
# -----------------------------------

# %%
## Plot ROC AUC Curve
from sklearn.metrics import roc_auc_score,roc_curve
plt.figure()

# Add the models to the list that you want to view on the ROC plot
auc_models = [
{
    'label': 'Adaboost Classifier',
    'model':  GradientBoostingClassifier(n_estimators=1000, min_samples_split=15,max_depth=15,loss="exponential",criterion="squared_error"),
    'auc':  0.8168
},
    
]
# create loop through all model
for algo in auc_models:
    model = algo['model'] # select the model
    model.fit(x_train, y_train) # train the model
# Compute False postive rate, and True positive rate
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(x_test)[:,1])
# Calculate Area under the curve to display on the plot
    plt.plot(fpr, tpr, label='%s ROC (area = %0.2f)' % (algo['label'], algo['auc']))
# Custom settings for the plot 
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
